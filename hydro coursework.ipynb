# %%
import numpy as np
import matplotlib.pyplot as plt
def u_U(y_h,Pi): return Pi*y_h*(y_h-1)+y_h

y_h = np.linspace(0,1)
for Pi in [-3,-2,-1,0,1,2,3]:
    plt.plot(u_U(y_h,Pi),y_h,label=Pi)
plt.legend(title=r'$\Pi$')
plt.xlabel('u/U')
plt.ylabel('y/h',rotation=0)
plt.show()

# %%
import numpy as np
import math
from matplotlib import pyplot as plt 
def u_u0(omega,t):
    return np.cos((omega*t)*Pi/180)

omega=np.linspace(0,1)
for t in [-3,-2,-1,0,1,2,3]:
    plt.plot(u_u0(omega,t),omega)
plt.xlabel('u/u0')
plt.ylabel('omega1')
plt.show()

# %%
import numpy as np
import math
from matplotlib import pyplot as plt 
def u_u0(z,omegat):
    return np.exp(-z)*np.cos(omegat-z)

omegat=np.arange(0,2*Pi,0.2)
z=np.arange(0,1,0.1)

for i in omegat:
    plt.plot(u_u0(z,i),z)
#plt.legend(title=r'$i$')
plt.xlabel('u/u0')
plt.ylabel('y_omega/2nu',rotation=1)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy
import math
from pylab import *

x = numpy.linspace(-4,4,200)
f1 = numpy.power(10,x)
f2=numpy.power(math.e,x)
f3 = numpy.power(2,x)

plt.plot(x,f1,'r',x,f2,'b',x,f3,'g',linewidth=2)
plt.axis([-4,4,-0.5,8])
plt.text(1,7.5,r'$10^x$',fontsize=16)
plt.text(2.2,7.5,r'$e^x$',fontsize=16)
plt.text(3.2,7.5,r'$2^x$',fontsize=16)
plt.title('A simple example',fontsize=16)

savefig('power.png',dpi=75)
show()

# %%
def ex(x):
    return numpy.power(math.e,x)

x=numpy.linspace(-4,4,200)
plt.plot(x,ex(x),linewidth=1)
plt.xlabel('x1')
plt.ylabel('ex',rotation=1)
#plt.title('e_n',fontsize=16)
plt.show()

#savefig('power.png',dpi=75)
#show()

# %%
def drag(rho,C_D,U,A):
    drag=1/2*rho*C_D*U**2*A
    return drag

c=drag(10**3,2,0.25,4)
print(c)

# %%
import numpy as np
import math
from matplotlib import pyplot as plt 
def du_dt(t,Pi):
    return Pi*np.sin(t)

t=np.linspace(0,1)
for Pi in [-3,-2,-1,0,1,2,3]:
    plt.plot(du_dt(t,Pi),t,label=Pi)
plt.legend(title=r'$\Pi$')
plt.xlabel('du/dt')
plt.ylabel('t',rotation=1)
plt.show()

# %%
import numpy as np
import math
from matplotlib import pyplot as plt 
def du_dt(t,Pi):
    return Pi*np.sin(t*pi/180)

t=np.linspace(0,1)
for Pi in [-3,-2,-1,0,1,2,3]:
    plt.plot(du_dt(t,Pi),t,label=Pi)
plt.legend(title=r'$\Pi$')
plt.xlabel('du/dt')
plt.ylabel('t',rotation=1)
plt.show()
